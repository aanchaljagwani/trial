# %% [markdown]
# <a href="https://colab.research.google.com/github/aanchaljagwani/trial/blob/main/TryG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO")
# Out:
# HELLO
